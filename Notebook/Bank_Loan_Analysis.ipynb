# %%
# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Display Options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Ignore Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Divyanshu\Desktop\Data Analytics Projects\Bank-Loan-Portfolio-Analysis\financial_loan.csv")

# %%
df = pd.read_csv("financial_loan.csv")

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     E           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     C           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %%
df.tail()
# Out:
#            id address_state application_type emp_length  \
# 38571  803452            NJ       INDIVIDUAL   < 1 year
# 38572  970377            NY       INDIVIDUAL    8 years
# 38573  875376            CA       INDIVIDUAL    5 years
# 38574  972997            NY       INDIVIDUAL    5 years
# 38575  682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership  issue_date  \
# 38571         Joseph M Sanzari Company     C       MORTGAGE  11-07-2021
# 38572                        Swat Fame     C           RENT  11-10-2021
# 38573  Anaheim Regional Medical Center     D           RENT  11-09-2021
# 38574               Brooklyn Radiology     D           RENT  11-10-2021
# 38575                    Allen Edmonds     F           RENT  11-07-2021
#
#       last_credit_pull_date last_payment_date loan_status next_payment_date  \
# 38571            16-05-2021        16-05-2021     Current        16-06-2021
# ...

# %%
df.sample(5, random_state=42)
# Out:
#             id address_state application_type emp_length  \
# 34007  1018442            HI       INDIVIDUAL  10+ years
# 24149   734525            GA       INDIVIDUAL   < 1 year
# 31634  1023158            MA       INDIVIDUAL    3 years
# 217     375143            NJ       INDIVIDUAL   < 1 year
# 25469   614599            OR       INDIVIDUAL  10+ years
#
#                                emp_title grade home_ownership  issue_date  \
# 34007                       US Air Force     E           RENT  11-11-2021
# 24149  Ed Voyles Chrysler Dodge Jeep Ram     E       MORTGAGE  11-05-2021
# 31634               Mercury Computer Sys     A       MORTGAGE  11-12-2021
# 217              United Natural Food Inc     A       MORTGAGE  09-01-2021
# 25469                  City of Pendleton     A       MORTGAGE  10-11-2021
#
#       last_credit_pull_date last_payment_date loan_status next_payment_date  \
# 34007            16-05-2021        14-10-2021  Fully Paid        14-11-2021
# ...

# %%
# 📊 Dataset Overview
print(f"Rows : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")
# Out:
# Rows : 38576
# Columns : 24

# %%
df.shape
# Out:
# (38576, 24)

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  object
#  8   last_credit_pull_date  38576 non-null  object
#  9   last_payment_date      38576 non-null  object
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  object
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id     member_id  annual_income           dti   installment  \
# count  3.857600e+04  3.857600e+04   3.857600e+04  38576.000000  38576.000000
# mean   6.810371e+05  8.476515e+05   6.964454e+04      0.133274    326.862965
# std    2.113246e+05  2.668105e+05   6.429368e+04      0.066662    209.092000
# min    5.473400e+04  7.069900e+04   4.000000e+03      0.000000     15.690000
# 25%    5.135170e+05  6.629788e+05   4.150000e+04      0.082100    168.450000
# 50%    6.627280e+05  8.473565e+05   6.000000e+04      0.134200    283.045000
# 75%    8.365060e+05  1.045652e+06   8.320050e+04      0.185900    434.442500
# max    1.077501e+06  1.314167e+06   6.000000e+06      0.299900   1305.190000
#
#            int_rate   loan_amount     total_acc  total_payment
# count  38576.000000  38576.000000  38576.000000   38576.000000
# mean       0.120488  11296.066855     22.132544   12263.348533
# std        0.037164   7460.746022     11.392282    9051.104777
# ...

# %%
df.describe(include='object')
# Out:
#        address_state application_type emp_length emp_title  grade  \
# count          38576            38576      38576     37138  38576
# unique            50                1         11     28525      7
# top               CA       INDIVIDUAL  10+ years   US Army      B
# freq            6894            38576       8870       135  11674
#
#        home_ownership  issue_date last_credit_pull_date last_payment_date  \
# count           38576       38576                 38576             38576
# unique              5          65                   107               102
# top              RENT  11-12-2021            16-05-2021        16-05-2021
# freq            18439        2188                 10041              1209
#
#        loan_status next_payment_date             purpose sub_grade  \
# count        38576             38576               38576     38576
# unique           3               102                  14        35
# ...

# %%
# 🔍 Data Quality Assessment
df.isnull().sum()
# Out:
# id                          0
# address_state               0
# application_type            0
# emp_length                  0
# emp_title                1438
# grade                       0
# home_ownership              0
# issue_date                  0
# last_credit_pull_date       0
# last_payment_date           0
# loan_status                 0
# next_payment_date           0
# member_id                   0
# purpose                     0
# sub_grade                   0
# term                        0
# verification_status         0
# annual_income               0
# dti                         0
# installment                 0
# int_rate                    0
# loan_amount                 0
# total_acc                   0
# total_payment               0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# id                       0.000000
# address_state            0.000000
# application_type         0.000000
# emp_length               0.000000
# emp_title                3.727706
# grade                    0.000000
# home_ownership           0.000000
# issue_date               0.000000
# last_credit_pull_date    0.000000
# last_payment_date        0.000000
# loan_status              0.000000
# next_payment_date        0.000000
# member_id                0.000000
# purpose                  0.000000
# sub_grade                0.000000
# term                     0.000000
# verification_status      0.000000
# annual_income            0.000000
# dti                      0.000000
# installment              0.000000
# int_rate                 0.000000
# loan_amount              0.000000
# total_acc                0.000000
# total_payment            0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# id                       38576
# address_state               50
# application_type             1
# emp_length                  11
# emp_title                28525
# grade                        7
# home_ownership               5
# issue_date                  65
# last_credit_pull_date      107
# last_payment_date          102
# loan_status                  3
# next_payment_date          102
# member_id                38576
# purpose                     14
# sub_grade                   35
# term                         2
# verification_status          3
# annual_income             5096
# dti                       2863
# installment              15132
# int_rate                   371
# loan_amount                880
# total_acc                   82
# total_payment            19525
# dtype: int64

# %%
df.dtypes
# Out:
# id                         int64
# address_state             object
# application_type          object
# emp_length                object
# emp_title                 object
# grade                     object
# home_ownership            object
# issue_date                object
# last_credit_pull_date     object
# last_payment_date         object
# loan_status               object
# next_payment_date         object
# member_id                  int64
# purpose                   object
# sub_grade                 object
# term                      object
# verification_status       object
# annual_income            float64
# dti                      float64
# installment              float64
# int_rate                 float64
# loan_amount                int64
# total_acc                  int64
# total_payment              int64
# dtype: object

# %%
# Check duplicate records

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicate rows

df = df.drop_duplicates()

print("Duplicate records removed successfully!")
# Out:
# Duplicate records removed successfully!

# %%
df.shape
# Out:
# (38576, 24)

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()}")
# Out:
# id: 38576
# address_state: 50
# application_type: 1
# emp_length: 11
# emp_title: 28525
# grade: 7
# home_ownership: 5
# issue_date: 65
# last_credit_pull_date: 107
# last_payment_date: 102
# loan_status: 3
# next_payment_date: 102
# member_id: 38576
# purpose: 14
# sub_grade: 35
# term: 2
# verification_status: 3
# annual_income: 5096
# dti: 2863
# installment: 15132
# int_rate: 371
# loan_amount: 880
# total_acc: 82
# total_payment: 19525

# %%
# Convert date columns into datetime format

date_columns = [
    "issue_date",
    "last_credit_pull_date",
    "last_payment_date",
    "next_payment_date"
]

for col in date_columns:
    df[col] = pd.to_datetime(df[col], dayfirst=True)

print(df[date_columns].dtypes)
# Out:
# issue_date               datetime64[ns]
# last_credit_pull_date    datetime64[ns]
# last_payment_date        datetime64[ns]
# next_payment_date        datetime64[ns]
# dtype: object

# %%
df[date_columns].head()
# Out:
#   issue_date last_credit_pull_date last_payment_date next_payment_date
# 0 2021-02-11            2021-09-13        2021-04-13        2021-05-13
# 1 2021-01-01            2021-12-14        2021-01-15        2021-02-15
# 2 2021-01-05            2021-12-12        2021-01-09        2021-02-09
# 3 2021-02-25            2021-12-12        2021-03-12        2021-04-12
# 4 2021-01-01            2021-12-14        2021-01-15        2021-02-15

# %%
df["emp_length"].unique()
# Out:
# array(['< 1 year', '9 years', '4 years', '10+ years', '3 years',
#        '5 years', '1 year', '6 years', '2 years', '7 years', '8 years'],
#       dtype=object)

# %%
df["term"].unique()
# Out:
# array([' 60 months', ' 36 months'], dtype=object)

# %%
df["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5333
# Current         1098
# Name: count, dtype: int64

# %%
df["verification_status"].value_counts()
# Out:
# verification_status
# Not Verified       16464
# Verified           12335
# Source Verified     9777
# Name: count, dtype: int64

# %%
df["home_ownership"].value_counts()
# Out:
# home_ownership
# RENT        18439
# MORTGAGE    17198
# OWN          2838
# OTHER          98
# NONE            3
# Name: count, dtype: int64

# %%
df["purpose"].value_counts()
# Out:
# purpose
# Debt consolidation    18214
# credit card            4998
# other                  3824
# home improvement       2876
# major purchase         2110
# small business         1776
# car                    1497
# wedding                 928
# medical                 667
# moving                  559
# house                   366
# vacation                352
# educational             315
# renewable_energy         94
# Name: count, dtype: int64

# %%
df["grade"].value_counts().sort_index()
# Out:
# grade
# A     9689
# B    11674
# C     7904
# D     5182
# E     2786
# F     1028
# G      313
# Name: count, dtype: int64

# %%
df["sub_grade"].value_counts().sort_index()
# Out:
# sub_grade
# A1    1052
# A2    1440
# A3    1740
# A4    2803
# A5    2654
# B1    1751
# B2    1990
# B3    2834
# B4    2455
# B5    2644
# C1    2089
# C2    1972
# C3    1490
# C4    1202
# C5    1151
# D1     913
# D2    1314
# D3    1144
# D4     960
# D5     851
# E1     750
# E2     640
# E3     538
# E4     448
# E5     410
# F1     325
# F2     243
# F3     182
# F4     163
# F5     115
# G1     101
# G2      78
# G3      48
# G4      56
# G5      30
# Name: count, dtype: int64

# %%
df["emp_length"].value_counts()
# Out:
# emp_length
# 10+ years    8870
# < 1 year     4575
# 2 years      4382
# 3 years      4088
# 4 years      3428
# 5 years      3273
# 1 year       3229
# 6 years      2228
# 7 years      1772
# 8 years      1476
# 9 years      1255
# Name: count, dtype: int64

# %%
df["address_state"].value_counts().head(10)
# Out:
# address_state
# CA    6894
# NY    3701
# FL    2773
# TX    2664
# NJ    1822
# IL    1486
# PA    1482
# VA    1375
# GA    1355
# MA    1310
# Name: count, dtype: int64

# %%
print("Minimum Loan :", df["loan_amount"].min())
print("Maximum Loan :", df["loan_amount"].max())
print("Average Loan :", round(df["loan_amount"].mean(),2))
# Out:
# Minimum Loan : 500
# Maximum Loan : 35000
# Average Loan : 11296.07

# %%
print("Minimum Income :", df["annual_income"].min())
print("Maximum Income :", df["annual_income"].max())
print("Average Income :", round(df["annual_income"].mean(),2))
# Out:
# Minimum Income : 4000.0
# Maximum Income : 6000000.0
# Average Income : 69644.54

# %%
print("Minimum Interest :", round(df["int_rate"].min()*100,2),"%")
print("Maximum Interest :", round(df["int_rate"].max()*100,2),"%")
print("Average Interest :", round(df["int_rate"].mean()*100,2),"%")
# Out:
# Minimum Interest : 5.42 %
# Maximum Interest : 24.59 %
# Average Interest : 12.05 %

# %%
round(df["verification_status"].value_counts(normalize=True)*100,2)
# Out:
# verification_status
# Not Verified       42.68
# Verified           31.98
# Source Verified    25.34
# Name: proportion, dtype: float64

# %%
round(df["loan_status"].value_counts(normalize=True)*100,2)
# Out:
# loan_status
# Fully Paid     83.33
# Charged Off    13.82
# Current         2.85
# Name: proportion, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                      id  member_id  annual_income       dti  installment  \
# id             1.000000   0.993609       0.012234  0.095496     0.090631
# member_id      0.993609   1.000000       0.013138  0.096723     0.085360
# annual_income  0.012234   0.013138       1.000000 -0.124877     0.267362
# dti            0.095496   0.096723      -0.124877  1.000000     0.053381
# installment    0.090631   0.085360       0.267362  0.053381     1.000000
# int_rate       0.083235   0.079246       0.050665  0.112978     0.280959
# loan_amount    0.146818   0.145916       0.268183  0.065713     0.929655
# total_acc      0.043469   0.045824       0.234334  0.230405     0.229785
# total_payment  0.144655   0.144906       0.254611  0.064319     0.857745
#
#                int_rate  loan_amount  total_acc  total_payment
# id             0.083235     0.146818   0.043469       0.144655
# member_id      0.079246     0.145916   0.045824       0.144906
# ...

# %%
df["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5333
# Current         1098
# Name: count, dtype: int64

# %%
df["loan_status_binary"] = df["loan_status"].map({
    "Fully Paid":1,
    "Current":1,
    "Charged Off":0
})

df[["loan_status","loan_status_binary"]].head()
# Out:
#    loan_status  loan_status_binary
# 0  Charged Off                   0
# 1   Fully Paid                   1
# 2  Charged Off                   0
# 3   Fully Paid                   1
# 4   Fully Paid                   1

# %%
df["emp_length"].unique()
# Out:
# array(['< 1 year', '9 years', '4 years', '10+ years', '3 years',
#        '5 years', '1 year', '6 years', '2 years', '7 years', '8 years'],
#       dtype=object)

# %%
df["emp_length"] = (
    df["emp_length"]
    .str.replace(" years","",regex=False)
    .str.replace(" year","",regex=False)
    .str.replace("+","",regex=False)
    .str.replace("< ","",regex=False)
)

df["emp_length"].head()
# Out:
# 0     1
# 1     9
# 2     4
# 3     1
# 4    10
# Name: emp_length, dtype: object

# %%
df["emp_length"] = pd.to_numeric(df["emp_length"],errors="coerce")

df["emp_length"].head()
# Out:
# 0     1
# 1     9
# 2     4
# 3     1
# 4    10
# Name: emp_length, dtype: int64

# %%
df["income_group"] = pd.cut(
    df["annual_income"],
    bins=[0,40000,80000,120000,10000000],
    labels=[
        "Low Income",
        "Middle Income",
        "Upper Middle",
        "High Income"
    ]
)

df["income_group"].value_counts()
# Out:
# income_group
# Middle Income    19037
# Low Income        9274
# Upper Middle      7015
# High Income       3250
# Name: count, dtype: int64

# %%
df["interest_category"] = pd.cut(
    df["int_rate"]*100,
    bins=[0,8,12,16,30],
    labels=[
        "Low",
        "Medium",
        "High",
        "Very High"
    ]
)

df["interest_category"].value_counts()
# Out:
# interest_category
# High         12599
# Medium       12377
# Low           7873
# Very High     5727
# Name: count, dtype: int64

# %%
df["loan_amount_group"] = pd.cut(
    df["loan_amount"],
    bins=[0,5000,10000,20000,40000],
    labels=[
        "Small Loan",
        "Medium Loan",
        "Large Loan",
        "Very Large Loan"
    ]
)

df["loan_amount_group"].value_counts()
# Out:
# loan_amount_group
# Medium Loan        12578
# Large Loan         12349
# Small Loan          9113
# Very Large Loan     4536
# Name: count, dtype: int64

# %%
df["dti_category"] = pd.cut(
    df["dti"],
    bins=[0,0.1,0.2,0.3],
    labels=[
        "Low",
        "Medium",
        "High"
    ]
)

df["dti_category"].value_counts()
# Out:
# dti_category
# Medium    18504
# Low       12630
# High       7269
# Name: count, dtype: int64

# %%
df["term"].value_counts()
# Out:
# term
# 36 months    28237
# 60 months    10339
# Name: count, dtype: int64

# %%
df["loan_term"] = df["term"].str.extract("(\d+)").astype(int)

df[["term","loan_term"]].head()
# Out:
#          term  loan_term
# 0   60 months         60
# 1   36 months         36
# 2   36 months         36
# 3   60 months         60
# 4   36 months         36

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  int64
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  datetime64[ns]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
sns.set_theme(style="whitegrid")

print("Visualization libraries imported successfully!")
# Out:
# Visualization libraries imported successfully!

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="loan_status",
    order=df["loan_status"].value_counts().index
)

plt.title("Loan Status Distribution")
plt.xlabel("Loan Status")
plt.ylabel("Number of Customers")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="grade",
    order=sorted(df["grade"].unique())
)

plt.title("Loan Grade Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="home_ownership",
    order=df["home_ownership"].value_counts().index
)

plt.title("Home Ownership")

plt.xticks(rotation=20)

plt.show()

# %%
plt.figure(figsize=(12,6))

sns.countplot(
    data=df,
    y="purpose",
    order=df["purpose"].value_counts().index
)

plt.title("Loan Purpose Distribution")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(
    data=df,
    x="emp_length",
    order=sorted(df["emp_length"].dropna().unique())
)

plt.title("Employment Experience")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="income_group",
    order=df["income_group"].value_counts().index
)

plt.title("Income Group Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="loan_amount_group",
    order=df["loan_amount_group"].value_counts().index
)

plt.title("Loan Amount Categories")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="interest_category",
    order=df["interest_category"].value_counts().index
)

plt.title("Interest Categories")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="verification_status",
    order=df["verification_status"].value_counts().index
)

plt.title("Verification Status")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df["loan_amount"],
    bins=30,
    kde=True
)

plt.title("Loan Amount Distribution")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df["annual_income"],
    bins=30,
    kde=True
)

plt.title("Annual Income Distribution")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df["int_rate"]*100,
    bins=30,
    kde=True
)

plt.title("Interest Rate Distribution (%)")

plt.show()

# %%
plt.figure(figsize=(10,4))

sns.boxplot(
    x=df["loan_amount"]
)

plt.title("Loan Amount Boxplot")

plt.show()

# %%
plt.figure(figsize=(10,4))

sns.boxplot(
    x=df["annual_income"]
)

plt.title("Annual Income Boxplot")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(
    data=df,
    x="grade",
    hue="loan_status",
    order=sorted(df["grade"].unique())
)

plt.title("Loan Status by Grade")
plt.xlabel("Grade")
plt.ylabel("Number of Loans")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(
    data=df,
    x="home_ownership",
    hue="loan_status",
    order=df["home_ownership"].value_counts().index
)

plt.title("Loan Status by Home Ownership")

plt.xticks(rotation=20)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(
    data=df,
    x="income_group",
    hue="loan_status"
)

plt.title("Loan Status by Income Group")

plt.show()

# %%
plt.figure(figsize=(9,5))

sns.countplot(
    data=df,
    x="verification_status",
    hue="loan_status"
)

plt.title("Verification Status vs Loan Status")

plt.show()

# %%
plt.figure(figsize=(12,7))

sns.countplot(
    data=df,
    y="purpose",
    hue="loan_status",
    order=df["purpose"].value_counts().index
)

plt.title("Loan Purpose vs Loan Status")

plt.show()

# %%
plt.figure(figsize=(9,5))

sns.barplot(
    data=df,
    x="grade",
    y="loan_amount",
    order=sorted(df["grade"].unique()),
    estimator="mean"
)

plt.title("Average Loan Amount by Grade")

plt.show()

# %%
plt.figure(figsize=(9,5))

sns.barplot(
    data=df,
    x="grade",
    y="annual_income",
    order=sorted(df["grade"].unique()),
    estimator="mean"
)

plt.title("Average Annual Income by Grade")

plt.show()

# %%
plt.figure(figsize=(9,5))

sns.barplot(
    data=df,
    x="grade",
    y="int_rate",
    order=sorted(df["grade"].unique()),
    estimator="mean"
)

plt.title("Average Interest Rate by Grade")

plt.ylabel("Interest Rate")

plt.show()

# %%
plt.figure(figsize=(10,6))

df["address_state"].value_counts().head(10).plot(kind="bar")

plt.title("Top 10 States by Loan Applications")
plt.ylabel("Applications")

plt.show()

# %%
plt.figure(figsize=(10,6))

df["purpose"].value_counts().head(10).plot(kind="barh")

plt.title("Top Loan Purposes")

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="annual_income",
    y="loan_amount",
    alpha=0.5
)

plt.title("Annual Income vs Loan Amount")

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="int_rate",
    y="loan_amount",
    alpha=0.5
)

plt.title("Interest Rate vs Loan Amount")

plt.show()

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    df.select_dtypes(include=["int64", "float64"]).corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
loan_status_percent = round(
    df["loan_status"].value_counts(normalize=True) * 100,
    2
)

print(loan_status_percent)
# Out:
# loan_status
# Fully Paid     83.33
# Charged Off    13.82
# Current         2.85
# Name: proportion, dtype: float64

# %%
income_percent = round(
    df["income_group"].value_counts(normalize=True) * 100,
    2
)

print(income_percent)
# Out:
# income_group
# Middle Income    49.35
# Low Income       24.04
# Upper Middle     18.18
# High Income       8.42
# Name: proportion, dtype: float64

# %%
grade_percent = round(
    df["grade"].value_counts(normalize=True) * 100,
    2
)

print(grade_percent)
# Out:
# grade
# B    30.26
# A    25.12
# C    20.49
# D    13.43
# E     7.22
# F     2.66
# G     0.81
# Name: proportion, dtype: float64

# %%
# Create Loan Amount Category

df["loan_amount_category"] = pd.cut(
    df["loan_amount"],
    bins=[0,5000,10000,15000,20000,40000],
    labels=[
        "Very Low",
        "Low",
        "Medium",
        "High",
        "Very High"
    ]
)

df["loan_amount_category"].value_counts()
# Out:
# loan_amount_category
# Low          12578
# Very Low      9113
# Medium        7842
# Very High     4536
# High          4507
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="loan_amount_category",
    order=df["loan_amount_category"].value_counts().index
)

plt.title("Loan Amount Categories")
plt.show()

# %%
df["income_category"] = pd.cut(
    df["annual_income"],
    bins=[0,40000,80000,120000,200000,1000000],
    labels=[
        "Low Income",
        "Middle Income",
        "Upper Middle",
        "High Income",
        "Very High"
    ]
)

df["income_category"].value_counts()
# Out:
# income_category
# Middle Income    19037
# Low Income        9274
# Upper Middle      7015
# High Income       2672
# Very High          564
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="income_category",
    order=df["income_category"].value_counts().index
)

plt.xticks(rotation=20)

plt.show()

# %%
# High Risk Customer
df["risk_level"] = np.where(
    df["int_rate"] > df["int_rate"].median(),
    "High Risk",
    "Low Risk"
)

df["risk_level"].value_counts()
# Out:
# risk_level
# Low Risk     19534
# High Risk    19042
# Name: count, dtype: int64

# %%
sns.countplot(
    data=df,
    x="risk_level"
)

plt.title("Risk Level Distribution")
plt.show()

# %%
pd.crosstab(
    df["risk_level"],
    df["loan_status"]
)
# Out:
# loan_status  Charged Off  Current  Fully Paid
# risk_level
# High Risk           3660      859       14523
# Low Risk            1673      239       17622

# %%
pd.crosstab(
    df["risk_level"],
    df["loan_status"],
    normalize="index"
)*100
# Out:
# loan_status  Charged Off   Current  Fully Paid
# risk_level
# High Risk      19.220670  4.511081   76.268249
# Low Risk        8.564554  1.223508   90.211938

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="risk_level",
    hue="loan_status"
)

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="annual_income",
    y="loan_amount",
    hue="loan_status"
)

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="annual_income",
    y="installment"
)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.boxplot(
    data=df,
    x="grade",
    y="int_rate"
)

plt.show()

# %%
df.groupby("grade")["loan_amount"].mean().sort_values()
# Out:
# grade
# A     8695.657447
# C    11064.834261
# B    11196.160271
# D    12335.160170
# E    15852.512563
# F    18395.379377
# G    20281.389776
# Name: loan_amount, dtype: float64

# %%
plt.figure(figsize=(8,5))

df.groupby("grade")["loan_amount"].mean().sort_values().plot(kind="bar")

plt.ylabel("Average Loan")

plt.show()

# %%
df.groupby("grade")["annual_income"].mean().sort_values()
# Out:
# grade
# A    67533.991024
# B    68320.577551
# C    68482.656662
# D    69092.806177
# E    78328.377943
# F    85115.680263
# G    94724.937732
# Name: annual_income, dtype: float64

# %%
df.groupby("grade")["total_payment"].mean().sort_values()
# Out:
# grade
# A     9087.786459
# B    12058.850009
# C    12142.398532
# D    13667.288885
# E    17646.859655
# F    20444.297665
# G    23214.239617
# Name: total_payment, dtype: float64

# %%
df.head()
# Out:
#         id address_state application_type  emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL           1                  Ryder
# 1  1072053            CA       INDIVIDUAL           9         MKC Accounting
# 2  1069243            CA       INDIVIDUAL           4  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL           1    barnes distribution
# 4  1068350            IL       INDIVIDUAL          10          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %%
print("="*60)
print("Final Dataset Overview")
print("="*60)

print(f"Rows    : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")

print("\nData Types")
print(df.dtypes)

print("\nMissing Values")
print(df.isnull().sum())

print("\nDuplicate Rows")
print(df.duplicated().sum())
# Out:
# ...
# Final Dataset Overview
# ...
# Rows    : 38576
# Columns : 33
#
# Data Types
# id                                int64
# address_state                    object
# application_type                 object
# emp_length                        int64
# emp_title                        object
# grade                            object
# home_ownership                   object
# issue_date               datetime64[ns]
# last_credit_pull_date    datetime64[ns]
# last_payment_date        datetime64[ns]
# loan_status                      object
# next_payment_date        datetime64[ns]
# member_id                         int64
# purpose                          object
# sub_grade                        object
# term                             object
# verification_status              object
# annual_income                   float64
# dti                             float64
# installment                     float64
# int_rate                        float64
# loan_amount                       int64
# ...

# %%
df["emp_title"] = df["emp_title"].fillna("Unknown")

# %%
df["dti_category"] = pd.cut(
    df["dti"],
    bins=[-1, 10, 20, 30, float("inf")],
    labels=[
        "Low",
        "Medium",
        "High",
        "Very High"
    ]
)

# %%
df["income_category"] = pd.cut(
    df["annual_income"],
    bins=[0, 40000, 80000, 120000, 200000, float("inf")],
    labels=[
        "Low Income",
        "Middle Income",
        "Upper Middle",
        "High Income",
        "Very High Income"
    ]
)

# %%
df[["emp_title", "dti_category", "income_category"]].isnull().sum()
# Out:
# emp_title          0
# dti_category       0
# income_category    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                       0
# address_state            0
# application_type         0
# emp_length               0
# emp_title                0
# grade                    0
# home_ownership           0
# issue_date               0
# last_credit_pull_date    0
# last_payment_date        0
# loan_status              0
# next_payment_date        0
# member_id                0
# purpose                  0
# sub_grade                0
# term                     0
# verification_status      0
# annual_income            0
# dti                      0
# installment              0
# int_rate                 0
# loan_amount              0
# total_acc                0
# total_payment            0
# loan_status_binary       0
# income_group             0
# interest_category        0
# loan_amount_group        0
# dti_category             0
# loan_term                0
# loan_amount_category     0
# income_category          0
# risk_level               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  int64
#  4   emp_title              38576 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  datetime64[ns]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
new_columns = [
    "income_group",
    "loan_amount_group",
    "interest_category",
    "dti_category",
    "risk_level",
    "loan_term"
]

df[new_columns].head()
# Out:
#     income_group loan_amount_group interest_category dti_category risk_level  \
# 0     Low Income        Small Loan              High          Low  High Risk
# 1  Middle Income        Small Loan         Very High          Low  High Risk
# 2  Middle Income        Large Loan              High          Low  High Risk
# 3  Middle Income        Small Loan            Medium          Low   Low Risk
# 4   Upper Middle        Small Loan               Low          Low   Low Risk
#
#    loan_term
# 0         60
# 1         36
# 2         36
# 3         60
# 4         36

# %%
df.head(10)
# Out:
#         id address_state application_type  emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL           1                  Ryder
# 1  1072053            CA       INDIVIDUAL           9         MKC Accounting
# 2  1069243            CA       INDIVIDUAL           4  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL           1    barnes distribution
# 4  1068350            IL       INDIVIDUAL          10          J&J Steel Inc
# 5  1062608            CA       INDIVIDUAL           3         Studio 94 Corp
# 6  1067441            TX       INDIVIDUAL          10      American Airlines
# 7  1066424            PA       INDIVIDUAL          10            SCI Mahanoy
# 8  1065254            FL       INDIVIDUAL          10         Tech Data Corp
# 9  1064589            MI       INDIVIDUAL          10     teltow contracting
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# ...

# %%
df.to_csv(
    r"C:\Users\Divyanshu\Desktop\Data Analytics Projects\Bank-Loan-Portfolio-Analysis\cleaned_financial_loan.csv",
    index=False
)

print("Cleaned dataset exported successfully!")
# Out:
# Cleaned dataset exported successfully!

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# %%
username = "postgres"
password = "admin1234"
host = "localhost"
port = "5432"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/postgres"
)

print("✅ Connected to PostgreSQL Server")
# Out:
# ✅ Connected to PostgreSQL Server

# %%
with engine.connect() as conn:
    conn = conn.execution_options(isolation_level="AUTOCOMMIT")

    conn.execute(text("""
        CREATE DATABASE bank_loan_analysis;
    """))

print("✅ Database 'bank_loan_analysis' created successfully!")

# %%
df.to_sql(
    "cleaned_financial_loan",
    engine,
    if_exists="replace",
    index=False
)

print("✅ Dataset uploaded successfully!")
# Out:
# ✅ Dataset uploaded successfully!

# %%
query = """
SELECT COUNT(*)
FROM cleaned_financial_loan;
"""

pd.read_sql(query, engine)
# Out:
#    count
# 0  38576

# %%
query = """
SELECT *
FROM cleaned_financial_loan
LIMIT 5;
"""

pd.read_sql(query, engine)
# Out:
#         id address_state application_type  emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL           1                  Ryder
# 1  1072053            CA       INDIVIDUAL           9         MKC Accounting
# 2  1069243            CA       INDIVIDUAL           4  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL           1    barnes distribution
# 4  1068350            IL       INDIVIDUAL          10          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %%
query = """
SELECT column_name, data_type
FROM information_schema.columns
WHERE table_name='cleaned_financial_loan';
"""

pd.read_sql(query, engine)
# Out:
#               column_name                    data_type
# 0           annual_income             double precision
# 1                     dti             double precision
# 2             installment             double precision
# 3                int_rate             double precision
# 4             loan_amount                       bigint
# 5               total_acc                       bigint
# 6           total_payment                       bigint
# 7      loan_status_binary                       bigint
# 8       next_payment_date  timestamp without time zone
# 9               member_id                       bigint
# 10             issue_date  timestamp without time zone
# 11  last_credit_pull_date  timestamp without time zone
# 12              loan_term                       bigint
# 13      last_payment_date  timestamp without time zone
# 14             emp_length                       bigint
# 15                     id                       bigint
# ...

# %%
from sqlalchemy import inspect

inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['cleaned_financial_loan']

# %%
print(engine.url)
# Out:
# postgresql+psycopg2://postgres:***@localhost:5432/postgres

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin1234@localhost:5432/bank_loan_analysis"
)

print(engine.url)
# Out:
# postgresql+psycopg2://postgres:***@localhost:5432/bank_loan_analysis

# %%
df.to_sql(
    "cleaned_financial_loan",
    engine,
    if_exists="replace",
    index=False
)

print("✅ Dataset uploaded successfully!")
# Out:
# ✅ Dataset uploaded successfully!
